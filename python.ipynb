# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\user\Desktop\ANALYTICS\datasets\datacleaning\HR.xlsx")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
columns_to_drop=['Over18','RelationshipSatisfaction','StandardHours', 'YearsSinceLastPromotion',]
df=df.drop(columns_to_drop,axis=1)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   DailyRate                1470 non-null   int64
#  4   Department               1470 non-null   object
#  5   DistanceFromHome         1470 non-null   int64
#  6   Education                1470 non-null   int64
#  7   EducationField           1470 non-null   object
#  8   EmployeeCount            1470 non-null   int64
#  9   EmployeeNumber           1470 non-null   int64
#  10  EnvironmentSatisfaction  1470 non-null   int64
#  11  Gender                   1470 non-null   object
#  12  HourlyRate               1470 non-null   int64
#  13  JobInvolvement           1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# DailyRate                  0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeNumber             0
# EnvironmentSatisfaction    0
# Gender                     0
# HourlyRate                 0
# JobInvolvement             0
# JobLevel                   0
# JobRole                    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# MonthlyRate                0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsWithCurrManager       0
# dtype: int64

# %%
df.nunique()
# Out:
# Age                          43
# Attrition                     2
# BusinessTravel                3
# DailyRate                   886
# Department                    3
# DistanceFromHome             29
# Education                     5
# EducationField                6
# EmployeeCount                 1
# EmployeeNumber             1470
# EnvironmentSatisfaction       4
# Gender                        2
# HourlyRate                   71
# JobInvolvement                4
# JobLevel                      5
# JobRole                       9
# JobSatisfaction               4
# MaritalStatus                 3
# MonthlyIncome              1349
# MonthlyRate                1427
# NumCompaniesWorked           10
# OverTime                      2
# PercentSalaryHike            15
# PerformanceRating             2
# StockOptionLevel              4
# TotalWorkingYears            40
# TrainingTimesLastYear         7
# WorkLifeBalance               4
# YearsAtCompany               37
# ...

# %%
df.sort_values(by="Age").head()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1311   18        No         Non-Travel       1431  Research & Development
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 972    18        No         Non-Travel       1124  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 296    18       Yes      Travel_Rarely        230  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1311                14          3        Medical              1
# 457                  5          3      Marketing              1
# 972                  1          3  Life Sciences              1
# 301                 10          3        Medical              1
# 296                  3          3  Life Sciences              1
#
#       EmployeeNumber  ...  OverTime PercentSalaryHike  PerformanceRating  \
# ...

# %%
df[df["BusinessTravel"].str.contains("Travel_Frequently")].head(50)
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 1     49        No  Travel_Frequently        279  Research & Development
# 3     33        No  Travel_Frequently       1392  Research & Development
# 5     32        No  Travel_Frequently       1005  Research & Development
# 8     38        No  Travel_Frequently        216  Research & Development
# 26    32       Yes  Travel_Frequently       1125  Research & Development
# 39    33        No  Travel_Frequently       1141                   Sales
# 43    27        No  Travel_Frequently        994                   Sales
# 44    30        No  Travel_Frequently        721  Research & Development
# 48    46        No  Travel_Frequently       1211                   Sales
# 55    33        No  Travel_Frequently        515  Research & Development
# 56    35        No  Travel_Frequently        853                   Sales
# 61    38        No  Travel_Frequently        653  Research & Development
# ...

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
df["EducationField"].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
df[df["EducationField"].str.contains("Other")].tail(50)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 611    35        No      Travel_Rarely        950  Research & Development
# 634    25        No      Travel_Rarely        141                   Sales
# 663    21       Yes      Travel_Rarely       1427  Research & Development
# 673    33        No      Travel_Rarely       1198  Research & Development
# 677    49        No      Travel_Rarely        527  Research & Development
# 680    36        No      Travel_Rarely        188  Research & Development
# 688    19       Yes      Travel_Rarely        419                   Sales
# 702    30        No      Travel_Rarely        231                   Sales
# 715    33        No  Travel_Frequently        827  Research & Development
# 725    35       Yes      Travel_Rarely        622  Research & Development
# 740    35        No      Travel_Rarely        802  Research & Development
# 761    36       Yes      Travel_Rarely        660  Research & Development
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
sns.barplot(x='NumCompaniesWorked', y='PerformanceRating',data=df)
# Out:
# <Axes: xlabel='NumCompaniesWorked', ylabel='PerformanceRating'>

# %%
sns.barplot(x='YearsInCurrentRole',y='JobSatisfaction',data=df)
# Out:
# <Axes: xlabel='YearsInCurrentRole', ylabel='JobSatisfaction'>

# %%
df[["Department","EducationField"]].head(50)
# Out:
#                 Department    EducationField
# 0                    Sales     Life Sciences
# 1   Research & Development     Life Sciences
# 2   Research & Development             Other
# 3   Research & Development     Life Sciences
# 4   Research & Development           Medical
# 5   Research & Development     Life Sciences
# 6   Research & Development           Medical
# 7   Research & Development     Life Sciences
# 8   Research & Development     Life Sciences
# 9   Research & Development           Medical
# 10  Research & Development           Medical
# 11  Research & Development     Life Sciences
# 12  Research & Development     Life Sciences
# 13  Research & Development           Medical
# 14  Research & Development     Life Sciences
# 15  Research & Development     Life Sciences
# 16  Research & Development     Life Sciences
# 17  Research & Development           Medical
# 18                   Sales     Life Sciences
# 19  Research & Development     Life Sciences
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.loc[df['EducationField']=='Marketing','Department']== 'Sales'
# Out:
# 27      True
# 29      True
# 36      True
# 37      True
# 46      True
#         ...
# 1446    True
# 1447    True
# 1453    True
# 1461    True
# 1462    True
# Name: Department, Length: 159, dtype: bool

# %%
df[['EducationField','Department']].head(50)
# Out:
#       EducationField              Department
# 0      Life Sciences                   Sales
# 1      Life Sciences  Research & Development
# 2              Other  Research & Development
# 3      Life Sciences  Research & Development
# 4            Medical  Research & Development
# 5      Life Sciences  Research & Development
# 6            Medical  Research & Development
# 7      Life Sciences  Research & Development
# 8      Life Sciences  Research & Development
# 9            Medical  Research & Development
# 10           Medical  Research & Development
# 11     Life Sciences  Research & Development
# 12     Life Sciences  Research & Development
# 13           Medical  Research & Development
# 14     Life Sciences  Research & Development
# 15     Life Sciences  Research & Development
# 16     Life Sciences  Research & Development
# 17           Medical  Research & Development
# 18     Life Sciences                   Sales
# 19     Life Sciences  Research & Development
# ...

# %%
df.loc[df['EducationField']=='Life Sciences','Department']='Research & Development'

# %%
df[['EducationField','Department']].tail(50)
# Out:
#         EducationField              Department
# 1420     Life Sciences  Research & Development
# 1421           Medical  Research & Development
# 1422           Medical  Research & Development
# 1423     Life Sciences  Research & Development
# 1424           Medical  Research & Development
# 1425           Medical  Research & Development
# 1426     Life Sciences  Research & Development
# 1427     Life Sciences  Research & Development
# 1428           Medical                   Sales
# 1429     Life Sciences  Research & Development
# 1430           Medical  Research & Development
# 1431         Marketing                   Sales
# 1432     Life Sciences  Research & Development
# 1433             Other                   Sales
# 1434     Life Sciences  Research & Development
# 1435           Medical  Research & Development
# 1436           Medical                   Sales
# 1437     Life Sciences  Research & Development
# 1438         Marketing                   Sales
# ...

# %%
df.loc[df['EducationField']=='Medical','Department']='Research & Development'

# %%
df[['EducationField','Department']].head()
# Out:
#   EducationField              Department
# 0  Life Sciences  Research & Development
# 1  Life Sciences  Research & Development
# 2          Other  Research & Development
# 3  Life Sciences  Research & Development
# 4        Medical  Research & Development

# %%
df[df["EducationField"].str.contains("Other")].tail(50)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 611    35        No      Travel_Rarely        950  Research & Development
# 634    25        No      Travel_Rarely        141                   Sales
# 663    21       Yes      Travel_Rarely       1427  Research & Development
# 673    33        No      Travel_Rarely       1198  Research & Development
# 677    49        No      Travel_Rarely        527  Research & Development
# 680    36        No      Travel_Rarely        188  Research & Development
# 688    19       Yes      Travel_Rarely        419                   Sales
# 702    30        No      Travel_Rarely        231                   Sales
# 715    33        No  Travel_Frequently        827  Research & Development
# 725    35       Yes      Travel_Rarely        622  Research & Development
# 740    35        No      Travel_Rarely        802  Research & Development
# 761    36       Yes      Travel_Rarely        660  Research & Development
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102  Research & Development
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  OverTime PercentSalaryHike  PerformanceRating  StockOptionLevel  \
# ...

# %%
sns.countplot(x='Age',hue='OverTime',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.barplot(y='JobSatisfaction',x='MaritalStatus',hue='Gender',data=df)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='JobSatisfaction'>

# %%
sns.barplot(y='PerformanceRating',x='MaritalStatus',hue='Gender',data=df)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='PerformanceRating'>

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102  Research & Development
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  OverTime PercentSalaryHike  PerformanceRating  StockOptionLevel  \
# ...

# %%
df.to_excel("hr1.xlsx")
